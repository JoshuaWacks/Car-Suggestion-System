# %%
# %matplotlib inline

import cv2
from matplotlib import pyplot as plt
import os
import numpy as np
from typing  import Tuple

# %%
save_folder_train = '../../data/Car Labelling/Standford Dataset/train/Acura Integra Type R 2001'
print(os.path.exists(save_folder_train))
# Out:
# True

# %%
img_path = os.path.join(save_folder_train,'00130.jpg')
img = cv2.imread(img_path)

cv2.imshow("img",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (372, 746, 3)

# %%
def resize_with_pad(image: np.array, 
                    new_shape: Tuple[int, int], 
                    padding_color: Tuple[int] = (255, 255, 255)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
image_size = 384
resized_image = resize_with_pad(img,[image_size,image_size])

# %%
# resized_image = cv2.resize(img, (new_width,new_height), cv2.INTER_LINEAR)

# Display the resized image (optional)
cv2.imshow("Resized Image", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resized_image.shape
# Out:
# (384, 384, 3)
