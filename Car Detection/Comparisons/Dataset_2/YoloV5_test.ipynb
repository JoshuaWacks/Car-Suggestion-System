# %%
# %matplotlib inline

import cv2
from matplotlib import pyplot as plt
import torch
import mlflow
from ultralytics import YOLO

from testing_logic_d2 import TestingLogicD2

import warnings
warnings.filterwarnings("ignore") 

torch.cuda.is_available()
torch.cuda.device_count()
# Out:
# 1

# %%
test = {'resize_images': False, 'resize_with_padding': False}
test['resize_images']
# Out:
# False

# %%
host = "127.0.0.1"
port = "8080"
mlflow.set_tracking_uri(uri=F"http://{host}:{port}")

# %%
model_type = "Yolo"
model_image_size = "1280"
model_use = "Car Detection"
hardware = "GPU"


resize_images = False
resize_with_padding = False

# %%
def run_experiment(model, params, exp_tags, exp_name): 
    
    mlflow.set_experiment(exp_name)

    testing_logic_d2 = TestingLogicD2()
    metrics = testing_logic_d2.test_model(model, params=params, experiment_tags=exp_tags)
    
    num_samples = 269 if params['dataset'] == 'train' else 57
    experiment_desc = F"Dataset: Dataset_2/{params['dataset']}.\nModel Use: {model_use} \nNumber of Samples: {num_samples} "

    run_name = F"{params['model_name']}-{params['dataset']}-ccm:{params['car_choice_metric']}"
    print(run_name)
    # Start an MLflow run
    with mlflow.start_run(run_name=run_name, description=experiment_desc,tags=exp_tags):
        # Log the hyperparameters
        mlflow.log_params(params)

        # Log the metrics
        for key,val in metrics.items():
            mlflow.log_metric(key, val)

# %%
exp_name = F"{model_use}. Dataset2. {model_type} Only. {hardware}. YoloV5 vs YoloV8 vs YoloV11"

for mn in ['yolo11m.pt','yolov5m','yolov8m.pt']:
    if mn == 'yolov5m':
        model = torch.hub.load('ultralytics/yolov5', mn, pretrained=True)
        model_type = 'Yolo'
    elif mn == 'yolov8m.pt' or mn == 'yolo11m.pt' :
        model = YOLO(mn) 
        model_type = 'Ultra_Yolo'

    for d in ['train','test']:
    # for d in ['train']:
        for cc_metric in ['confidence','area']:
        # for cc_metric in ['area']:
            for rim in [False]:
                for rwp in [False]:
                    car_choice_metric = cc_metric
                    dataset = d

                    params = {
                        "resize_images": rim,
                        "resize_with_padding": rwp,
                        "car_choice_metric": car_choice_metric,
                        'model_name':mn,
                        "model_type": model_type,
                        "dataset": dataset,

                    }
                    experiment_tags = {
                        "dataset": F"Dataset_2/{dataset}",
                        "model_use": model_use,
                        "hardware": F"{hardware}"
                    }
                    print(params)
                    print(experiment_tags)
                    print("\n")

                    # if rim==False and rwp==True:
                    #     continue


                    run_experiment(model=model,
                                    params=params,
                                    exp_tags=experiment_tags,
                                    exp_name=exp_name)
# Out:
# {'resize_images': False, 'resize_with_padding': False, 'car_choice_metric': 'confidence', 'model_name': 'yolo11m.pt', 'model_type': 'Ultra_Yolo', 'dataset': 'train'}
# {'dataset': 'Dataset_2/train', 'model_use': 'Car Detection', 'hardware': 'GPU'}
#
#
#
# 0: 480x640 1 car, 55.0ms
# Speed: 2.9ms preprocess, 55.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 2 cars, 57.0ms
# Speed: 1.4ms preprocess, 57.0ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 car, 5 birds, 55.1ms
# Speed: 1.8ms preprocess, 55.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 11 persons, 5 cars, 4 trucks, 19.8ms
# Speed: 1.4ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 20.8ms
# Speed: 1.7ms preprocess, 20.8ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 18.8ms
# Speed: 1.5ms preprocess, 18.8ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 2 cars, 5 bottles, 14.9ms
# Speed: 1.5ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 4 persons, 1 car, 1 truck, 1 backpack, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 14 persons, 7 cars, 1 backpack, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 22.0ms
# Speed: 1.5ms preprocess, 22.0ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 surfboard, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x544 12 persons, 1 car, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 544x640 1 bicycle, 4 cars, 1 truck, 1 bird, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 1.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 12 persons, 2 cars, 1 umbrella, 19.9ms
# Speed: 1.5ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.5ms
# Speed: 1.4ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 1 truck, 21.3ms
# Speed: 1.4ms preprocess, 21.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 21.8ms
# Speed: 1.3ms preprocess, 21.8ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 20.8ms
# Speed: 1.5ms preprocess, 20.8ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 1 truck, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 5 cars, 3 trucks, 22.2ms
# Speed: 1.6ms preprocess, 22.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 21.0ms
# Speed: 1.9ms preprocess, 21.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 1 truck, 1 parking meter, 20.9ms
# Speed: 1.6ms preprocess, 20.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 22.6ms
# Speed: 1.4ms preprocess, 22.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 17.7ms
# Speed: 1.3ms preprocess, 17.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 15.0ms
# Speed: 1.4ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 8 cars, 22.5ms
# Speed: 1.5ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.0ms
# Speed: 1.3ms preprocess, 15.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 4 cars, 22.3ms
# Speed: 1.5ms preprocess, 22.3ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 9 cars, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 5 cars, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 22.3ms
# Speed: 1.4ms preprocess, 22.3ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 20.9ms
# Speed: 1.4ms preprocess, 20.9ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 cars, 22.0ms
# Speed: 1.9ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 15.6ms
# Speed: 1.3ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 15.1ms
# Speed: 1.4ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 20.7ms
# Speed: 1.5ms preprocess, 20.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 15.3ms
# Speed: 1.5ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 2 cars, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 5 cars, 21.4ms
# Speed: 1.6ms preprocess, 21.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 car, 61.6ms
# Speed: 1.7ms preprocess, 61.6ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 352x640 1 car, 19.8ms
# Speed: 1.2ms preprocess, 19.8ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 7 persons, 5 cars, 1 bus, 22.3ms
# Speed: 1.3ms preprocess, 22.3ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 1 car, 16.4ms
# Speed: 1.5ms preprocess, 16.4ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 19.3ms
# Speed: 1.4ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 23.1ms
# Speed: 1.6ms preprocess, 23.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 22.4ms
# Speed: 1.1ms preprocess, 22.4ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 persons, 3 cars, 2 bottles, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 truck, 1 stop sign, 4 chairs, 1 refrigerator, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 20.5ms
# Speed: 1.8ms preprocess, 20.5ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 21.9ms
# Speed: 1.6ms preprocess, 21.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.7ms
# Speed: 1.6ms preprocess, 20.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 3 persons, 1 car, 22.2ms
# Speed: 1.3ms preprocess, 22.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 cars, 1 potted plant, 21.9ms
# Speed: 1.3ms preprocess, 21.9ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 20.7ms
# Speed: 1.3ms preprocess, 20.7ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 13 persons, 2 cars, 1 handbag, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 7 boats, 22.1ms
# Speed: 1.6ms preprocess, 22.1ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 4 cars, 1 truck, 22.6ms
# Speed: 1.4ms preprocess, 22.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 person, 1 car, 2 boats, 20.7ms
# Speed: 1.4ms preprocess, 20.7ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 car, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 car, 22.2ms
# Speed: 1.2ms preprocess, 22.2ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 480x640 1 car, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 10 persons, 7 cars, 4 umbrellas, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 1 bus, 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 1 kite, 20.4ms
# Speed: 1.6ms preprocess, 20.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 22.6ms
# Speed: 1.7ms preprocess, 22.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 4 persons, 6 cars, 1 traffic light, 22.1ms
# Speed: 1.6ms preprocess, 22.1ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 6 persons, 1 car, 1 traffic light, 16.1ms
# Speed: 1.3ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 13 persons, 5 cars, 1 truck, 2 suitcases, 21.0ms
# Speed: 1.6ms preprocess, 21.0ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 22.1ms
# Speed: 1.6ms preprocess, 22.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 13 persons, 1 car, 1 handbag, 21.0ms
# Speed: 1.9ms preprocess, 21.0ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 truck, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 cars, 18.1ms
# Speed: 1.3ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 9 persons, 1 car, 2 handbags, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 7 cars, 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 22.6ms
# Speed: 1.6ms preprocess, 22.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.3ms
# Speed: 1.4ms preprocess, 21.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 person, 1 car, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 22.5ms
# Speed: 1.2ms preprocess, 22.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 21.8ms
# Speed: 1.5ms preprocess, 21.8ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 22.5ms
# Speed: 1.1ms preprocess, 22.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 21.9ms
# Speed: 1.6ms preprocess, 21.9ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 1 person, 1 car, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 16.2ms
# Speed: 1.1ms preprocess, 16.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 14 persons, 1 car, 15.7ms
# Speed: 1.3ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 17.7ms
# Speed: 1.2ms preprocess, 17.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.3ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 22.3ms
# Speed: 1.5ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 21.8ms
# Speed: 1.3ms preprocess, 21.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 22.2ms
# Speed: 1.4ms preprocess, 22.2ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 car, 15.5ms
# Speed: 1.1ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 15.4ms
# Speed: 1.2ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.8ms
# Speed: 1.6ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 12 persons, 1 car, 1 handbag, 21.7ms
# Speed: 1.8ms preprocess, 21.7ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 320x640 1 car, 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 480x640 1 car, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.3ms
# Speed: 1.6ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.6ms
# Speed: 1.6ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.8ms
# Speed: 1.4ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.8ms
# Speed: 1.7ms preprocess, 21.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.2ms preprocess, 16.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.8ms
# Speed: 1.1ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 512x640 1 car, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 480x640 1 car, 21.7ms
# Speed: 1.7ms preprocess, 21.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 21.1ms
# Speed: 1.6ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 19.6ms
# Speed: 1.4ms preprocess, 19.6ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.6ms
# Speed: 1.3ms preprocess, 16.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 22.1ms
# Speed: 1.4ms preprocess, 22.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.6ms
# Speed: 1.9ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 22.7ms
# Speed: 1.8ms preprocess, 22.7ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.2ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.2ms
# Speed: 1.4ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 288x640 3 cars, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 1 car, 21.5ms
# Speed: 1.3ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 27.1ms
# Speed: 1.6ms preprocess, 27.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 24.4ms
# Speed: 2.3ms preprocess, 24.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 4 cars, 29.6ms
# Speed: 1.7ms preprocess, 29.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 21.0ms
# Speed: 1.5ms preprocess, 21.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.9ms
# Speed: 1.2ms preprocess, 16.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 22.1ms
# Speed: 1.2ms preprocess, 22.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 car, 18.7ms
# Speed: 1.2ms preprocess, 18.7ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 416x640 2 persons, 1 car, 3 chairs, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 car, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 car, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 448x640 1 car, 22.8ms
# Speed: 1.5ms preprocess, 22.8ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 20.7ms
# Speed: 1.9ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 2 cars, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 1 person, 1 car, 23.8ms
# Speed: 1.3ms preprocess, 23.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 car, 19.3ms
# Speed: 1.3ms preprocess, 19.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 17.7ms
# Speed: 1.3ms preprocess, 17.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 18.9ms
# Speed: 1.4ms preprocess, 18.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 18.4ms
# Speed: 1.7ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.9ms
# Speed: 2.4ms preprocess, 16.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 20.1ms
# Speed: 1.5ms preprocess, 20.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 19.9ms
# Speed: 0.9ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 17.1ms
# Speed: 1.2ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 18.3ms
# Speed: 1.6ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 motorcycle, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 320x640 2 cars, 17.2ms
# Speed: 1.2ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 416x640 1 car, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 car, 20.1ms
# Speed: 1.5ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 persons, 1 car, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 7 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 car, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 14.9ms
# Speed: 3.2ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 18.0ms
# Speed: 2.9ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 cars, 16.1ms
# Speed: 2.9ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 15.2ms
# Speed: 2.9ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 car, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.3ms
# Speed: 1.2ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 6 persons, 2 cars, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 16.9ms
# Speed: 1.3ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.1ms
# Speed: 1.2ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.4ms
# Speed: 1.3ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 15.7ms
# Speed: 1.3ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 320x640 1 car, 15.9ms
# Speed: 0.9ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 448x640 1 car, 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 512x640 1 car, 15.9ms
# Speed: 1.3ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 car, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 14.9ms
# Speed: 1.4ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 3 persons, 1 car, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 6 persons, 7 cars, 1 truck, 1 bench, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 15.7ms
# Speed: 1.5ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 2 persons, 1 car, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 3 cars, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 1 traffic light, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 car, 24.0ms
# Speed: 1.3ms preprocess, 24.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 3 persons, 2 cars, 23.8ms
# Speed: 2.4ms preprocess, 23.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 22.6ms
# Speed: 1.6ms preprocess, 22.6ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 2 cars, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 cars, 1 truck, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 persons, 7 cars, 1 umbrella, 22.3ms
# Speed: 2.6ms preprocess, 22.3ms inference, 4.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 1 motorcycle, 16.1ms
# Speed: 1.5ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 28.1ms
# Speed: 1.8ms preprocess, 28.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 4 cars, 15.5ms
# Speed: 1.2ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 14 persons, 2 cars, 1 truck, 1 backpack, 19.9ms
# Speed: 1.5ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 bus, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 17.8ms
# Speed: 1.4ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 bus, 1 truck, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 2 cars, 15.6ms
# Speed: 1.6ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 cars, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 4.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 6 persons, 2 cars, 1 bottle, 5 chairs, 2 tvs, 30.0ms
# Speed: 1.6ms preprocess, 30.0ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 cars, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 bicycle, 4 cars, 2 trucks, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 14 persons, 10 cars, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 512x640 11 persons, 1 car, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 352x640 2 persons, 4 cars, 30.2ms
# Speed: 1.6ms preprocess, 30.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 480x640 2 cars, 31.2ms
# Speed: 1.6ms preprocess, 31.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 person, 1 car, 2 trucks, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 1 car, 81.5ms
# Speed: 1.4ms preprocess, 81.5ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 car, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 4.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 256x640 1 car, 57.8ms
# Speed: 1.1ms preprocess, 57.8ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 448x640 13 persons, 1 car, 1 handbag, 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 22.6ms
# Speed: 1.4ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 320x640 2 cars, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 480x640 13 cars, 23.2ms
# Speed: 1.6ms preprocess, 23.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 4 cars, 1 truck, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 car, 1 motorcycle, 18.4ms
# Speed: 4.0ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 person, 10 cars, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 16.8ms
# Speed: 1.8ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 13 cars, 20.8ms
# Speed: 1.3ms preprocess, 20.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 1 car, 16.9ms
# Speed: 1.5ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 car, 17.3ms
# Speed: 1.2ms preprocess, 17.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 2 trucks, 24.1ms
# Speed: 1.9ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 1 car, 3 benchs, 21.4ms
# Speed: 2.2ms preprocess, 21.4ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 6 cars, 21.9ms
# Speed: 1.9ms preprocess, 21.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 persons, 3 cars, 2 trucks, 20.2ms
# Speed: 2.7ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 22.8ms
# Speed: 2.5ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 269
# 269
# yolo11m.pt-train-ccm:confidence
# 🏃 View run yolo11m.pt-train-ccm:confidence at: http://127.0.0.1:8080/#/experiments/152725141320416361/runs/a6b5b65799be49deab627727fd3575b6
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/152725141320416361
# {'resize_images': False, 'resize_with_padding': False, 'car_choice_metric': 'area', 'model_name': 'yolo11m.pt', 'model_type': 'Ultra_Yolo', 'dataset': 'train'}
# {'dataset': 'Dataset_2/train', 'model_use': 'Car Detection', 'hardware': 'GPU'}
#
#
#
# 0: 480x640 1 car, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 16.0ms
# Speed: 1.2ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 2 cars, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 car, 5 birds, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 3.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 11 persons, 5 cars, 4 trucks, 29.5ms
# Speed: 1.5ms preprocess, 29.5ms inference, 4.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 31.9ms
# Speed: 2.3ms preprocess, 31.9ms inference, 4.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 2 cars, 5 bottles, 30.6ms
# Speed: 1.6ms preprocess, 30.6ms inference, 4.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 4 persons, 1 car, 1 truck, 1 backpack, 20.4ms
# Speed: 1.8ms preprocess, 20.4ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 14 persons, 7 cars, 1 backpack, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 surfboard, 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x544 12 persons, 1 car, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 544x640 1 bicycle, 4 cars, 1 truck, 1 bird, 31.8ms
# Speed: 2.7ms preprocess, 31.8ms inference, 4.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 12 persons, 2 cars, 1 umbrella, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 1 truck, 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 18.9ms
# Speed: 1.6ms preprocess, 18.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 1 truck, 21.6ms
# Speed: 1.5ms preprocess, 21.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 5 cars, 3 trucks, 21.4ms
# Speed: 1.6ms preprocess, 21.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 1 truck, 1 parking meter, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 16.7ms
# Speed: 1.3ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 8 cars, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 16.9ms
# Speed: 1.6ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 31.5ms
# Speed: 1.5ms preprocess, 31.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 4 cars, 26.4ms
# Speed: 1.8ms preprocess, 26.4ms inference, 4.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 9 cars, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 5 cars, 23.6ms
# Speed: 1.7ms preprocess, 23.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 22.7ms
# Speed: 2.1ms preprocess, 22.7ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 21.9ms
# Speed: 2.3ms preprocess, 21.9ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 cars, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 22.2ms
# Speed: 1.7ms preprocess, 22.2ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 20.9ms
# Speed: 1.7ms preprocess, 20.9ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 29.6ms
# Speed: 1.7ms preprocess, 29.6ms inference, 3.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 23.4ms
# Speed: 2.4ms preprocess, 23.4ms inference, 3.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 cars, 22.1ms
# Speed: 2.3ms preprocess, 22.1ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 2 cars, 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 5 cars, 24.7ms
# Speed: 1.7ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 car, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 352x640 1 car, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 7 persons, 5 cars, 1 bus, 18.3ms
# Speed: 1.5ms preprocess, 18.3ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 1 car, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 18.5ms
# Speed: 1.9ms preprocess, 18.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 416x640 1 car, 18.7ms
# Speed: 1.1ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 car, 21.6ms
# Speed: 1.7ms preprocess, 21.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 16.9ms
# Speed: 1.6ms preprocess, 16.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 persons, 3 cars, 2 bottles, 21.9ms
# Speed: 1.9ms preprocess, 21.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 truck, 1 stop sign, 4 chairs, 1 refrigerator, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 3 persons, 1 car, 18.4ms
# Speed: 1.4ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 cars, 1 potted plant, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 30.9ms
# Speed: 1.6ms preprocess, 30.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 31.2ms
# Speed: 2.3ms preprocess, 31.2ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 13 persons, 2 cars, 1 handbag, 22.1ms
# Speed: 1.9ms preprocess, 22.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 7 boats, 35.9ms
# Speed: 1.9ms preprocess, 35.9ms inference, 4.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 4 cars, 1 truck, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 person, 1 car, 2 boats, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 car, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 car, 21.9ms
# Speed: 1.3ms preprocess, 21.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 480x640 1 car, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 10 persons, 7 cars, 4 umbrellas, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 1 bus, 16.4ms
# Speed: 1.4ms preprocess, 16.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 1 kite, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 4.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 4 persons, 6 cars, 1 traffic light, 31.0ms
# Speed: 1.6ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 6 persons, 1 car, 1 traffic light, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 13 persons, 5 cars, 1 truck, 2 suitcases, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.4ms
# Speed: 1.4ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 13 persons, 1 car, 1 handbag, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 truck, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 cars, 17.7ms
# Speed: 1.4ms preprocess, 17.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 9 persons, 1 car, 2 handbags, 17.0ms
# Speed: 1.7ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 7 cars, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 21.4ms
# Speed: 2.1ms preprocess, 21.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 15.0ms
# Speed: 1.7ms preprocess, 15.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 person, 1 car, 16.9ms
# Speed: 1.6ms preprocess, 16.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 17.1ms
# Speed: 1.3ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 21.5ms
# Speed: 1.1ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 20.4ms
# ...
#
# 0: 480x640 1 car, 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# 269
# 269
# yolov8m.pt-train-ccm:area
# 🏃 View run yolov8m.pt-train-ccm:area at: http://127.0.0.1:8080/#/experiments/152725141320416361/runs/fbdee1c02a1745f4a0507ba1cd01e22d
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/152725141320416361
# {'resize_images': False, 'resize_with_padding': False, 'car_choice_metric': 'confidence', 'model_name': 'yolov8m.pt', 'model_type': 'Ultra_Yolo', 'dataset': 'test'}
# {'dataset': 'Dataset_2/test', 'model_use': 'Car Detection', 'hardware': 'GPU'}
#
#
#
# 0: 384x640 1 car, 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 persons, 2 bicycles, 1 car, 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 persons, 9 cars, 13.6ms
# Speed: 1.8ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 3 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 7 persons, 1 bicycle, 2 cars, 1 motorcycle, 12.7ms
# Speed: 1.6ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 1 car, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 truck, 13.3ms
# Speed: 1.6ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 2 bicycles, 2 cars, 2 motorcycles, 1 truck, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 13.4ms
# Speed: 1.6ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 2 trucks, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 truck, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 576x640 4 cars, 34.1ms
# Speed: 2.4ms preprocess, 34.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 480x640 3 persons, 2 cars, 2 trucks, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 5 persons, 4 cars, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 person, 1 car, 1 truck, 17.7ms
# Speed: 1.5ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 motorcycle, 14.2ms
# Speed: 1.3ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 27.1ms
# Speed: 1.7ms preprocess, 27.1ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 25.2ms
# Speed: 1.7ms preprocess, 25.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 24.4ms
# Speed: 1.4ms preprocess, 24.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 14.2ms
# Speed: 1.4ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bus, 1 truck, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 29.4ms
# Speed: 1.3ms preprocess, 29.4ms inference, 4.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 1 car, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 2 cars, 16.5ms
# Speed: 1.6ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 car, 14.2ms
# Speed: 2.8ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 3 cars, 15.1ms
# Speed: 1.4ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 17.3ms
# Speed: 1.3ms preprocess, 17.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 1 bench, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 320x640 1 car, 1 boat, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 cars, 19.6ms
# Speed: 1.3ms preprocess, 19.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 car, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 448x640 1 car, 1 bird, 13.4ms
# Speed: 1.6ms preprocess, 13.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 15.4ms
# Speed: 1.1ms preprocess, 15.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# 57
# 57
# yolov8m.pt-test-ccm:confidence
# 🏃 View run yolov8m.pt-test-ccm:confidence at: http://127.0.0.1:8080/#/experiments/152725141320416361/runs/2293d2739c74411c8095c0c3de3febea
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/152725141320416361
# {'resize_images': False, 'resize_with_padding': False, 'car_choice_metric': 'area', 'model_name': 'yolov8m.pt', 'model_type': 'Ultra_Yolo', 'dataset': 'test'}
# {'dataset': 'Dataset_2/test', 'model_use': 'Car Detection', 'hardware': 'GPU'}
#
#
#
# 0: 384x640 1 car, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 persons, 2 bicycles, 1 car, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 persons, 9 cars, 18.6ms
# Speed: 1.4ms preprocess, 18.6ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 13.7ms
# Speed: 1.6ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 person, 3 cars, 25.2ms
# Speed: 1.6ms preprocess, 25.2ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 7 persons, 1 bicycle, 2 cars, 1 motorcycle, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 14.8ms
# Speed: 1.4ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 25.4ms
# Speed: 2.5ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 1 car, 26.0ms
# Speed: 1.4ms preprocess, 26.0ms inference, 4.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 1 truck, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 2 bicycles, 2 cars, 2 motorcycles, 1 truck, 17.6ms
# Speed: 1.5ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 cars, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 14.4ms
# Speed: 1.5ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 person, 1 car, 2 trucks, 21.5ms
# Speed: 1.4ms preprocess, 21.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 truck, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 576x640 4 cars, 14.2ms
# Speed: 4.0ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 480x640 3 persons, 2 cars, 2 trucks, 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 5 persons, 4 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 person, 1 car, 1 truck, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 15.6ms
# Speed: 1.4ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 motorcycle, 14.1ms
# Speed: 1.2ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 17.7ms
# Speed: 1.6ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 13.5ms
# Speed: 1.1ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.1ms
# Speed: 1.4ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 13.4ms
# Speed: 1.2ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 17.0ms
# Speed: 1.3ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bus, 1 truck, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.6ms
# Speed: 1.8ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 car, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 1 car, 17.9ms
# Speed: 1.4ms preprocess, 17.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 2 cars, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 car, 13.7ms
# Speed: 2.9ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 13.5ms
# Speed: 1.3ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 2 cars, 1 potted plant, 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 3 cars, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 2 cars, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 18.9ms
# Speed: 1.6ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 car, 1 bench, 20.7ms
# Speed: 2.4ms preprocess, 20.7ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 car, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 car, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 320x640 1 car, 1 boat, 17.7ms
# Speed: 1.4ms preprocess, 17.7ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 384x640 2 cars, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 car, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 448x640 1 car, 1 bird, 19.3ms
# Speed: 1.5ms preprocess, 19.3ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 1 car, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# 57
# 57
# yolov8m.pt-test-ccm:area
# 🏃 View run yolov8m.pt-test-ccm:area at: http://127.0.0.1:8080/#/experiments/152725141320416361/runs/50c1712ccf6c4b21bee77b07b26f8afd
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/152725141320416361

# %% [markdown]
# There is no need for > YoloV5

# %% [markdown]
# YoloV5m/YoloV5m6 will suffice
